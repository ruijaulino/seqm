# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('dark_background')
import models

# %%
phi=np.array([0.8,0.2])
means=[
        np.array([0.1]),
        np.array([-0.1])
    ] # let the means be different from zero 

# list of covariance matrices (for each mixture)
covs=[
    np.array([[0.1]]),
    np.array([[0.5]])
]
# number of data points to generate
n=500 

x,z=models.simulate_mvgmm(n,phi,means,covs)

# %%
gm=models.GaussianMixture(n_states=2,n_gibbs=3,f_burn=0.1,max_k=0.25)
gm.estimate(x)
gm.view()
# Out:
# ---------
# [[41.86691536]]
# [[0.18774402]]
# 0.18850701003773723
# ---------
# ---------
# [[52.96602777]]
# [[0.1912131]]
# 0.1918446458624694
# ---------
# ---------
# [[52.56492245]]
# [[0.24335612]]
# 0.24418443675647267
# ---------
# ---------
# [[42.10699906]]
# [[0.14826408]]
# 0.1466947559308659
# ---------
# ** Gaussian Mixture **
# State 1
# Prob:  0.2905793301890578
# Mean
# [0.08355474]
# Covariance
# [[0.19880466]]
# State 2
# Prob:  0.37608733647760895
# Mean
# [0.00013335]
# Covariance
# [[0.16948633]]

# %%
print(sdfsdf)

State 1
Prob:  0.8205168173523089
Mean
[0.12581968]
Covariance
[[0.09945751]]


State 2
Prob:  0.17948318264769103
Mean
[-0.22277807]
Covariance
[[0.55097536]]
# Out:
#   File "<ipython-input-4-0ae401946ed5>", line 3
#     State 1
#           ^
# SyntaxError: invalid syntax
