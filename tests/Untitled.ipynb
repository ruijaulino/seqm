# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
import importlib
plt.style.use('dark_background')

# %%
sys.path.insert(0, '../seqm')

# %%
# setting path
try:
    importlib.reload(model_pipe)
except:
    import model_pipe
try:
    importlib.reload(models)
except:
    import models
try:
    importlib.reload(generators)
except:
    import generators
try:
    importlib.reload(dataset)
except:
    import dataset    
try:
    importlib.reload(models)
except:
    import models  
try:
    importlib.reload(post_process)
except:
    import post_process

# %%
# Conditional Gaussian/Mixture
# data now contains observed states, for example model for different weekdays
phi=np.array([0.8,0.2])
means=[
        np.array([0.1]),
        np.array([-0.1])
    ] # let the means be different from zero 
# list of covariance matrices (for each mixture)
covs=[
    np.array([[0.1]]),
    np.array([[0.5]])
]
# number of data points to generate
n=500 
data=generators.linear(n=1000,a=0,b=0.1,start_date='2000-01-01')
dataset_obj=dataset.Dataset({'dataset 1':data})	
# create model
model=models.ConditionalGaussian(n_gibbs=None,kelly_std=2,max_w=1)
model_pipes=model_pipe.ModelPipes(model)
for key in dataset_obj.keys():
    model_pipe_ = model_pipe.ModelPipe()
    model_pipes[key] = model_pipe_

paths=dataset_obj.cvbt(
                model_pipes, 
                k_folds=4, 
                seq_path=False, 
                start_fold=0, 
                n_paths=4, 
                burn_fraction=0.1, 
                min_burn_points=3, 
                share_model=True, 
                view_models=False
                )
post_process.portfolio_post_process(paths)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 42.99it/s]
# ** REJECT STRATEGY **
# ** PERFORMANCE SUMMARY **
#
# Return:  0.00021377264858534573
# Standard deviation:  0.005672815008400042
# Sharpe:  0.03768369817609089

# %%
# HMM
# simple HMM 
# simulate and fit
A=np.array([
            [0.9,0.1],
            [0.1,0.9]
        ]) # state transition

P=np.array([0.5,0.5]) # initial state distribution

means=[
        np.array([0.1]),
        np.array([-0.1])
    ] # let the means be different from zero 

# list of covariance matrices (for each mixture)
covs=[
    np.array([[0.1]]),
    np.array([[0.5]])
]
# number of data points to generate
n=2000 
x,z=generators.simulate_hmm(n,A,P,means,covs)

dates=pd.date_range('2000-01-01',periods=n,freq='B')
data=pd.DataFrame(x,columns=['y1'],index=dates)


dataset_obj=dataset.Dataset({'dataset 1':data})	
# create model
model=models.GaussianHMM(n_states=2,n_gibbs=100,kelly_std=2,max_w=1)
model_pipes=model_pipe.ModelPipes(model)
for key in dataset_obj.keys():
    model_pipe_ = model_pipe.ModelPipe()
    model_pipes[key] = model_pipe_

paths=dataset_obj.cvbt(
                model_pipes, 
                k_folds=4, 
                seq_path=False, 
                start_fold=0, 
                n_paths=4, 
                burn_fraction=0.1, 
                min_burn_points=3, 
                share_model=True, 
                view_models=False
                )
post_process.portfolio_post_process(paths)
# Out:
#   0%|                                                                                            | 0/4 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 37
#      34     model_pipe_ = model_pipe.ModelPipe()
#      35     model_pipes[key] = model_pipe_
# ---> 37 paths=dataset_obj.cvbt(
#      38                 model_pipes,
#      39                 k_folds=4,
#      40                 seq_path=False,
#      41                 start_fold=0,
#      42                 n_paths=4,
#      43                 burn_fraction=0.1,
#      44                 min_burn_points=3,
#      45                 share_model=True,
#      46                 view_models=False
#      47                 )
#      48 post_process.portfolio_post_process(paths)
#
# File ~\Desktop\seqm\tests\../seqm\dataset.py:221, in Dataset.cvbt(self, model_pipes, k_folds, seq_path, start_fold, n_paths, burn_fraction, min_burn_points, view_models, **kwargs)
#     212 for fold_index in range(start_fold, k_folds):
#     213 	# make a copy of the original model_pipes
#     214 	local_model_pipes = self.set_train_test_fold(
#     215 												model_pipes=copy.deepcopy(model_pipes),
#     216 												test_index=fold_index,
#    (...)
#     219 												seq_path=seq_path
#     220 												)
# --> 221 	local_model_pipes.estimate()
#     222 	local_model_pipes.evaluate()
#     223 	path.add(local_model_pipes)
#
# File ~\Desktop\seqm\tests\../seqm\model_pipe.py:273, in ModelPipes.estimate(self)
#     256 def estimate(self):
#     258 	if self.master_model is not None:
#     259 		# if the model is shared then we train a single model
#     260 		# on all data joined
#    (...)
#     271 		# 	x=None
#     272 		# y=np.vstack(y)
# --> 273 		x = np.vstack([e.x_train for k,e in self.items()])
#     274 		y = np.vstack([e.y_train for k,e in self.items()])
#     275 		if x.shape[1] == 0:
#
# File ~\anaconda3\lib\site-packages\numpy\core\shape_base.py:289, in vstack(tup, dtype, casting)
#     287 if not isinstance(arrs, list):
#     288     arrs = [arrs]
# --> 289 return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#
# ValueError: need at least one array to concatenate
